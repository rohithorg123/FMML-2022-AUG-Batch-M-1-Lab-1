# %% [markdown]
# <a href="https://colab.research.google.com/github/rohithorg123/FMML-2022-AUG-Batch-M-1-Lab-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-25 16:13:10--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   375MB/s    in 0.2s
#
# 2023-05-25 16:13:14 (375 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5400    1308.3381v3  This paper considers the problem of networks r...  stat
# 20117   1410.2442v2  RCC8 is a popular fragment of the region conne...    cs
# 17357  1710.06917v2  Stories are a vital form of communication in h...    cs
# 11931  1704.03711v1  Hidden Markov Models (HMMs) are a ubiquitous t...  stat
# 8772   cs/0408037v1  We investigate the possibility of modelling th...    cs
# ...             ...                                                ...   ...
# 17821  1803.04291v1  In language modeling, it is difficult to incor...    cs
# 2951   1802.05385v1  We demonstrate that state-of-the-art optical c...    cs
# 12698   1311.1406v1  We propose a novel topic discovery algorithm f...    cs
# 33157  1803.00314v1  Ensemble methods are a cornerstone of modern m...    cs
# 10899  1612.02751v1  Computational approaches to drug discovery can...  stat
#
#                                                    title  year  \
# 5400   High dimensional Sparse Gaussian Graphical Mix...  2013
# 20117       Realizing RCC8 networks using convex regions  2014
# 17357  Annotating High-Level Structures of Short Stor...  2017
# 11931  Investigation on the use of Hidden-Markov Mode...  2017
# 8772   Multi-dimensional Type Theory: Rules, Categori...  2004
# ...                                                  ...   ...
# 17821  Entity-Aware Language Model as an Unsupervised...  2018
# 2951    Fooling OCR Systems with Adversarial Text Images  2018
# 12698  TOP-SPIN: TOPic discovery via Sparse Principal...  2013
# 33157  Diversity and degrees of freedom in regression...  2018
# 10899  Protein-Ligand Scoring with Convolutional Neur...  2016
#
#                                                 keywords
# 5400   [considers, reconstruction, heterogeneous, gra...
# 20117  [connection, qualitative, relations, adjacency...
# 17357  [communication, computational, understanding, ...
# 11931  [ubiquitous, automatic, transcription, segment...
# 8772   [investigate, possibility, modelling, semantic...
# ...                                                  ...
# 17821  [difficult, incorporate, relationships, knowle...
# 2951   [demonstrate, character, recognition, vulnerab...
# 12698  [discovery, algorithm, unlabeled, framework, d...
# 33157  [cornerstone, performance, crucially, diversit...
# 10899  [computational, approaches, discovery, associa...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5400     [considers, reconstruction, heterogeneous, gra...
# 20117    [connection, qualitative, relations, adjacency...
# 17357    [communication, computational, understanding, ...
# 11931    [ubiquitous, automatic, transcription, segment...
# 8772     [investigate, possibility, modelling, semantic...
#                                ...
# 6596     [introduced, parameters, selecting, appropriat...
# 35299    [optimization, algorithm, simulated, annealing...
# 11002    [coordinate, minimization, initially, partitio...
# 3231     [dictionary, algorithms, successfully, reconst...
# 7488     [techniques, normalization, performance, theor...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8884 words.
# Out of those 4590 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="310536d7-0080-420f-a4f4-53faf50f88b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("310536d7-0080-420f-a4f4-53faf50f88b2")) {                    Plotly.newPlot(                        "310536d7-0080-420f-a4f4-53faf50f88b2",                        [{"x":["degeneracy","selection","heterogeneous","variables","consistent","estimates","parameters","application","performance","identifiability","expectation","parameter","estimator","simulations","regularity","considers","demonstrate","conditions","reconstruction","challenging","resulting","likelihood","graphical","precision","penalized","coefficients","technique","dimensional","algorithm","maximization","estimation","represented","applications","connection","respectively","essentially","reasoning","relations","qualitative","interested","conceptual","euclidean","adjacency","restricted","partially","surprisingly","realizing","constrains","refinements","typically","expressed","restriction","furthermore","guarantee","especially","functional","categorization","annotated","annotation","narrative","computational","developed","understanding","operationalization","collected","intelligently","communication","extending","communications","narratives","challenge","consolidating","including","annotating","structures","instrument","investigation","framework","component","improvements","integrating","ubiquitous","processing","depending","sequential","identifying","repertoires","correcting","repertoire","different","transitions","automatic","comparatively","polyphonic","segmentation","transcription","noticeable","probabilistic","evaluated","candidate","explicitly","multiplicity","possibility","semantics","implementations","perspective","dimension","addressed","complicated","operations","dimensions","investigate","important","categories","pragmatics","additional","constraints","traditional","interpretation","modelling","algorithms","formalized","prediction","successive","efficiently","regression","principled","demonstrated","considered","predictions","independent","considerations","introduce","practical","generalising","optimisation","scenarios","discovered","optimising","unnecessary","stability","optimization","effective","available","commercial","industrial","optimizing","reduction","carefully","classification","automatically","comparing","unauthorized","databases","attendance","recognition","management","recognize","verification","environment","classroom","representations","representation","separable","visualization","projection","indicators","information","construct","customize","informative","objective","visualizations","restricts","illustrated","dependent","viewpoint","perceptually","organizing","statement","predictable","vocabulary","processes","describes","nonterminal","motivation","invariant","discussion","stationary","understood","repetitive","proposition","properties","postulates","consistency","bioinformatics","corrupted","excluding","infection","effectiveness"],"y":[1,160,34,133,80,55,240,250,892,1,28,96,36,45,8,32,532,117,110,280,150,69,55,71,9,33,249,178,800,24,196,78,430,44,84,24,120,88,53,23,22,28,7,50,41,23,5,8,3,106,36,10,168,33,114,38,11,65,64,5,319,194,174,2,68,4,65,32,7,6,176,1,251,16,127,3,26,528,105,99,30,15,276,27,79,69,0,10,3,733,12,197,3,7,197,8,7,154,121,57,74,4,38,113,40,70,58,29,40,62,42,131,330,68,4,107,149,201,60,50,576,9,218,23,147,94,19,88,139,91,138,8,328,158,2,16,79,21,3,10,33,305,263,326,15,20,50,94,35,481,199,79,4,49,3,382,60,46,47,119,4,222,357,13,31,48,8,665,93,3,34,170,5,4,22,62,29,6,17,7,6,32,105,99,3,17,58,23,24,20,8,8,183,4,73,12,16,4,2,193],"type":"bar"},{"x":["degeneracy","selection","heterogeneous","variables","consistent","estimates","parameters","application" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4590,), (4590, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Ordering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>and</span> <span style=''>Semantic</span> <span style=''>aware</span> <span style=''>Topic</span> <span style=''>Modeling</span> <br/><br/><span style=''>Topic</span> <span style=''>modeling</span> <span style=''>of</span> <span style=''>textual</span> <span style=''>corpora</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4141414141414141);'>challenging</span> <span style=''>problem</span> <span style=''>In</span> <span style=''>most</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>the</span> <span style=''>bag</span> <span style=''>of</span> <span style=''>words</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>is</span> <span style=''>usually</span> <span style=''>made</span> <span style=''>which</span> <span style=''>ignores</span> <span style=''>the</span> <span style=''>ordering</span> <span style=''>of</span> <span style=''>words</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simplifies</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>but</span> <span style=''>it</span> <span style=''>unrealistically</span> <span style=''>loses</span> <span style=''>the</span> <span style=''>ordering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>and</span> <span style=''>the</span> <span style=''>semantic</span> <span style=''>of</span> <span style=''>words</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>Mixture</span> <span style=''>Neural</span> <span style=''>Topic</span> <span style=''>Model</span> <span style=''>(GMNTM)</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporates</span> <span style=''>both</span> <span style=''>the</span> <span style=''>ordering</span> <span style=''>of</span> <span style=''>words</span> <span style=''>and</span> <span style=''>the</span> <span style=''>semantic</span> <span style=''>meaning</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.9189189189189189);'>sentences</span> <span style=''>into</span> <span style=''>topic</span> <span style=''>modeling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represent</span> <span style=''>each</span> <span style=''>topic</span> <span style=''>as</span> <span style=''>a</span> <span style=''>cluster</span> <span style=''>of</span> <span style=''>multi</span> <span style='background-color:rgba(255, 0, 0, 0.339517625231911);'>dimensional</span> <span style=''>vectors</span> <span style=''>and</span> <span style=''>embed</span> <span style=''>the</span> <span style=''>corpus</span> <span style=''>into</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>vectors</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>mixture</span> <span style=''>model</span> <span style=''>Each</span> <span style=''>word</span> <span style=''>is</span> <span style=''>affected</span> <span style=''>not</span> <span style=''>only</span> <span style=''>by</span> <span style=''>its</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Large</span> <span style=''>Scale</span> <span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Application</span> <span style=''>to</span> <span style=''>Text</span> <span style=''>Data</span> <br/><br/><span style=''>Sparse</span> <span style=''>PCA</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>small</span> <span style=''>number</span> <span style=''>of</span> <span style=''>features</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximizes</span> <span style=''>variance</span> <span style=''>across</span> <span style=''>data</span> <span style=''>Although</span> <span style=''>Sparse</span> <span style=''>PCA</span> <span style=''>has</span> <span style=''>apparent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantages</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>PCA</span> <span style=''>such</span> <span style=''>as</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style=''>thought</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style=''>much</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surprising</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>sparse</span> <span style=''>PCA</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easier</span> <span style=''>than</span> <span style=''>PCA</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>and</span> <span style=''>that</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style=''>reliably</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>very</span> <span style=''>large</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>This</span> <span style=''>comes</span> <span style=''>from</span> <span style=''>a</span> <span style=''>rigorous</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>elimination</span> <span style=''>pre</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>result</span> <span style=''>coupled</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>favorable</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>features</span> <span style=''>in</span> <span style=''>real</span> <span style=''>life</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponentially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decreasing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variances</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>for</span> <span style=''>many</span> <span style=''>features</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eliminat ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Non</span> <span style=''>convex</span> <span style=''>Robust</span> <span style=''>PCA</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>for</span> <span style=''>robust</span> <span style=''>PCA</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recovering</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style=''>from</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>corruptions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>of</span> <span style=''>unknown</span> <span style=''>value</span> <span style=''>and</span> <span style=''>support</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>involves</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternating</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projecting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>residuals</span> <span style=''>onto</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrices</span> <span style=''>and</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>sparse</span> <span style=''>matrices</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>is</span> <span style=''>em</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>but</span> <span style=''>easy</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>In</span> <span style=''>spite</span> <span style=''>of</span> <span style=''>this</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3103448275862069);'>convexity</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.375886524822695);'>establish</span> <span style=''>exact</span> <span style=''>recovery</span> <span style=''>of</span> <span style=''>the</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style=''>under</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>required</span> <span style=''>by</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>(which</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style=''>convex</span> <span style=''>optimization)</span> <span style=''>For</span> <span style=''>an</span> <span style=''>m</span> <span style=''>times</span> <span style=''>n</span> <span style=''>input</span> <span style=''>matrix</span> <span style=''>(m</span> <span style=''>leq</span> <span style=''>n)</span> <span style=''>our</span> <span style=''>method</span> <span style=''>has</span> <span style=''>a</span> <span style=''>running</span> <span style=''>time</span> <span style=''>of</span> <span style=''>O(r2mn)</span> <span style=''>per</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>and</span> <span style=''>needs</span> <span style=''>O(log(1epsilon))</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterations</span> <span style=''>to</span> <span style=''>reach</span> <span style=''>an</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>epsilon</span> <span style=''>This</span> <span style=''>is</span> <span style=''>close</span> <span style=''>to</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Entropy</span> <span style=''>Isomap</span> <span style=''>Manifold</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>Dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Scientific</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>produce</span> <span style=''>massive</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>as</span> <span style=''>highly</span> <span style=''>non</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformations</span> <span style=''>of</span> <span style=''>an</span> <span style=''>initial</span> <span style=''>state</span> <span style=''>and</span> <span style=''>few</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>Mapping</span> <span style=''>such</span> <span style=''>data</span> <span style=''>to</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>manifold</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>facilitate</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>process</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ultimately</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>off</span> <span style=''>the</span> <span style=''>shelf</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Isomap</span> <span style=''>fail</span> <span style=''>for</span> <span style=''>such</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>primarily</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>strong</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>among</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>belonging</span> <span style=''>to</span> <span style=''>the</span> <span style=''>same</span> <span style=''>process</span> <span style=''>pathways</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>Entropy</span> <span style=''>Isomap</span> <span style=''>to</span> <span style=''>address</span> <span style=''>this</span> <span style=''>issue</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successfully</span> <span style=''>applied</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>morphology</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10028653295128939)
# 	representation (0.12786532951289398)
# 	architecture (0.08524355300859598)
# 	segmentation (0.07055873925501432)
# 	evaluation (0.1010028653295129)
# 	knowledge (0.14290830945558738)
# 	different (0.2625358166189112)
# 	convolutional (0.11712034383954155)
# 	detection (0.12285100286532952)
# 	recognition (0.13681948424068768)
#
# Some Statistics words are:
# 	statistical (0.14292828685258965)
# 	theoretical (0.14840637450199204)
# 	stochastic (0.13794820717131473)
# 	variables (0.14641434262948208)
# 	distribution (0.17828685258964144)
# 	estimation (0.17231075697211157)
# 	inference (0.18725099601593626)
# 	algorithm (0.39691235059760954)
# 	dimensional (0.1797808764940239)
# 	regression (0.19223107569721115)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b9a184cd-e37b-4f3b-ad44-3b94f43920d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9a184cd-e37b-4f3b-ad44-3b94f43920d7")) {                    Plotly.newPlot(                        "b9a184cd-e37b-4f3b-ad44-3b94f43920d7",                        [{"x":["degeneracy","selection","heterogeneous","variables","consistent","estimates","parameters","application","performance","identifiability","expectation","parameter","estimator","simulations","regularity","considers","demonstrate","conditions","reconstruction","challenging","resulting","likelihood","graphical","precision","penalized","coefficients","technique","dimensional","algorithm","maximization","estimation","represented","applications","connection","respectively","essentially","reasoning","relations","qualitative","interested","conceptual","euclidean","adjacency","restricted","partially","surprisingly","realizing","constrains","refinements","typically","expressed","restriction","furthermore","guarantee","especially","functional","categorization","annotated","annotation","narrative","computational","developed","understanding","operationalization","collected","intelligently","communication","extending","communications","narratives","challenge","consolidating","including","annotating","structures","instrument","investigation","framework","component","improvements","integrating","ubiquitous","processing","depending","sequential","identifying","repertoires","correcting","repertoire","different","transitions","automatic","comparatively","polyphonic","segmentation","transcription","noticeable","probabilistic","evaluated","candidate","explicitly","multiplicity","possibility","semantics","implementations","perspective","dimension","addressed","complicated","operations","dimensions","investigate","important","categories","pragmatics","additional","constraints","traditional","interpretation","modelling","algorithms","formalized","prediction","successive","efficiently","regression","principled","demonstrated","considered","predictions","independent","considerations","introduce","practical","generalising","optimisation","scenarios","discovered","optimising","unnecessary","stability","optimization","effective","available","commercial","industrial","optimizing","reduction","carefully","classification","automatically","comparing","unauthorized","databases","attendance","recognition","management","recognize","verification","environment","classroom","representations","representation","separable","visualization","projection","indicators","information","construct","customize","informative","objective","visualizations","restricts","illustrated","dependent","viewpoint","perceptually","organizing","statement","predictable","vocabulary","processes","describes","nonterminal","motivation","invariant","discussion","stationary","understood","repetitive","proposition","properties","postulates","consistency","bioinformatics","corrupted","excluding","infection","effectiveness","unlabeled","generalization","comparisons","detection","classifier","conducted","sufficient","comparable","healthcare","theoretical","simultaneous","mislabeled","empirical","configurations","virtually","trajectories","unlimited","synthetic","investigating","rendering","labelling","physically","photorealistic","expanding","geometric","previously","providing","techniques","relatively","simulated","computation","sensitive","difference","sensitivity","accelerated","approximation","computing","quadratic","efficiency","asymptotically","experiments","efficient","computationally","significantly","developments","allocation","benchmark","convergence","algorithmic","illustrate","complexity","assumptions","dependence","reservoir","infinitely","explor ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	repertoires
# 	integrative
# 	depression
# 	repulsion
# 	sketching
# 	cytometry
# 	parsimony
# 	kernelization
# 	blockmodels
# 	invertibility
# 	subgaussian
# 	textitfixed
# 	autoencoding
# 	preconditioned
# 	semiparametric
# 	ultrahigh
# 	climatology
# 	novelties
# 	stationarities
# 	blackwells
# Some words which never appear in Statistics papers:
# 	realizing
# 	operationalization
# 	narratives
# 	annotating
# 	multiplicity
# 	pragmatics
# 	unauthorized
# 	attendance
# 	perceptually
# 	nonterminal
# 	repetitive
# 	postulates
# 	unlimited
# 	tensorizing
# 	defeasible
# 	argumentation
# 	nonmonotonic
# 	dialectal
# 	formalisation
# 	discipline

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.075976622577668e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7616666666666667
